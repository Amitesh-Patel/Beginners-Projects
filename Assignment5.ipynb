# %%
import csv
#from CSE102_5523P3 import f_get_menu_option


print("\nWORLD CUP SOCCER ANALYSIS PROGRAM")

print("\n------------------------------------------------------------------------------------------------------------------------")

print("\n(1) Print Group Play Game Summary")

print("\n(2) Report Teams (s) having maximum value for requested statistic")

print("\n(3) Report Teams (s) having minimum value for requested statistic")

print("\n(4) Report Teams (s) having value greater than average for requested statistic")
print("\n(5) Report Teams (s) having value less than average for requested statistic")
print("\n(9) End Program")
print("\n------------------------------------------------------------------------------------------------------------------------")
a=1
while(a):
  file = input("Enter a filename to processes")
  with open(file, 'r') as csvfile:
    ln=  csv.reader(csvfile, delimiter = ',')
    data = []
    for line in ln:
      data.append(line)
  cmd = int(input("\nEnter a number to choose a command:\n"))
  if cmd == 1:
    i=1
    print(f"\ngame#      score         date      hour         category      team1      team2")
    b=1
    while(b):
      try:
        game = data[i][0]
        date = data[i][1]
        time = data[i][2]
        category = data[i][3]
        team1 = data[i][4]
        goal_for = data[i][5]
        goal_aga = data[i][6]
        team2 = data[i+1][4]
        i+=2
        print(f"\n  {game}       {goal_for}-{goal_aga}      {date}       {time}           {category}        {team1}           {team2}")
      except:
        b=0


  if cmd == 2:
    user_input = input("Enter Statistics name to report :\n")

    if (user_input=="goals for"):
      a=[]
      for i in data[1:]:
        a.append((i[5],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")


    elif (user_input=="goals against"):
      a=[]
      for i in data[1:]:
        a.append((i[6],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="yellow cards"):
      a=[]
      for i in data[1:]:
        a.append((i[7],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="red cards"):
      a=[]
      for i in data[1:]:
        a.append((i[8],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="possession percent"):
      a=[]
      for i in data[1:]:
        a.append((i[9],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="attempts"):
      a=[]
      for i in data[1:]:
        a.append((i[10],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="fouls"):
      a=[]
      for i in data[1:]:
        a.append((i[11],i[4]))
      b = max(a)[0]
      m  = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="offsides"):
      a=[]
      for i in data[1:]:
        a.append((i[12],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="passes attempted"):
      a=[]
      for i in data[1:]:
        a.append((i[13],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="passes completed"):
      a=[]
      for i in data[1:]:
        a.append((i[14],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")


    elif (user_input=="corner kicks"):
      a=[]
      for i in data[1:]:
        a.append((i[15],i[4]))
      b = max(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")
      for i in m:
        print(f"\t{i}")

    elif (user_input=="goals prevented"):
      a=[]
      for i in data[1:]:
        a.append((i[16],i[4]))
      b = max(a)[0]   #got the maximum value
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])   #now append the country name which is having maximum value
      m.sort()
      print(f"\nReporting teams having game(s) with highest number of {user_input} ({b}) :")              
      for i in m:          
        print(f"\t{i}")     #printing in alphanumeric form 


  elif cmd ==3:
    user_input = input("Enter Statistics name to report :\n")

    if (user_input=="goals for"):
      a=[]
      for i in data[1:]:
        a.append((i[5],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="goals against"):
      a=[]
      for i in data[1:]:
        a.append((i[6],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")


    elif (user_input=="yellow cards"):
      a=[]
      for i in data[1:]:
        a.append((i[7],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="red cards"):
      a=[]
      for i in data[1:]:
        a.append((i[8],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="possession percent"):
      a=[]
      for i in data[1:]:
        a.append((i[9],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="attempts"):
      a=[]
      for i in data[1:]:
        a.append((i[10],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="fouls"):
      a=[]
      for i in data[1:]:
        a.append((i[11],i[4]))
      b = min(a)[0]
      m  = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="offsides"):
      a=[]
      for i in data[1:]:
        a.append((i[12],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="passes attempted"):
      a=[]
      for i in data[1:]:
        a.append((i[13],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="passes completed"):
      a=[]
      for i in data[1:]:
        a.append((i[14],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")


    elif (user_input=="corner kicks"):
      a=[]
      for i in data[1:]:
        a.append((i[15],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")

    elif (user_input=="goals prevented"):
      a=[]
      for i in data[1:]:
        a.append((i[16],i[4]))
      b = min(a)[0]
      m = []
      for i in a:
        if b==i[0]:
          m.append(i[1])
      my_set = set(m)
      my_list = list(my_set)
      my_list.sort()
      print(f"\nReporting teams having game(s) with lowest number of {user_input} ({b}) :")
      for i in my_list:
        print(f"\t{i}")



  if cmd == 4:
    user_input = input("Enter Statistics name to report:\n")

    if (user_input=="goals for"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[5],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="goals against"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[6],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="yellow cards"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[7],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="red cards"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[8],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="possession percent"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[9],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="fouls"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[10],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="offside"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[11],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="passes attempted"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[12],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="passes completed"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[13],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="goals prevented"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[14],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="corner kicks"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[15],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="goals prevented"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[16],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])>mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with greater than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    


  if cmd==5:
    user_input = input("Enter Statistics name to report :\n")

    if (user_input=="goals for"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[5],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="goals against"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[6],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="yellow cards"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[7],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="red cards"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[8],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="possession percent"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[9],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="fouls"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[10],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="fouls"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[11],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="offside"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[12],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="passes attempted"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[13],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="passes completed"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[14],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")


    elif (user_input=="corner kicks"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[15],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

    elif (user_input=="goals prevented"):
      a=[]
      b=[]
      for i in data[1:]:
        a.append((i[16],i[4]))
      my_list = [int(x[0]) for x in a]
      mean = sum(my_list) / len(my_list)
      dup=[]
      for i in a:
        if (int(i[0])<mean):
          dup.append(i[1])
      my_set = set(dup)
      lst = list(my_set)
      lst.sort()
      print(f"\nReporting teams having games with less than average {user_input} ({mean}) :")
      for i in lst:
        print(f"\t{i}")

  if cmd == 9:
    a=0
# Out:
# WORLD CUP SOCCER ANALYSIS PROGRAM
#
# ------------------------------------------------------------------------------------------------------------------------
#
# (1) Print Group Play Game Summary
#
# (2) Report Teams (s) having maximum value for requested statistic
#
# (3) Report Teams (s) having minimum value for requested statistic
#
# (4) Report Teams (s) having value greater than average for requested statistic
#
# (5) Report Teams (s) having value less than average for requested statistic
#
# (9) End Program
#
# ------------------------------------------------------------------------------------------------------------------------
# Enter a filename to processes/content/worldcupdata_4 2.csv
#
# Enter a number to choose a command:
# 1
#
# game#      score         date      hour         category      team1      team2
#
#   1       0-2      20-Nov-22       17:00           Group A        QATAR           ECUADOR
#
# ...

# %%
1
